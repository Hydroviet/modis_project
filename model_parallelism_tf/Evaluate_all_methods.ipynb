# %%
import os
import numpy as np
from dtw import dtw
import matplotlib.pyplot as plt

from modis_utils.misc import cache_data, restore_data

# %% [markdown]
# # ERCL

# %%
groundtruth_ercl, predict_ercl = restore_data('visualize/test/groundtruth_predict_water_area.dat')
euclidean_norm = lambda x, y: np.abs(x - y)

d, cost_matrix, acc_cost_matrix, path = dtw(groundtruth_ercl, predict_ercl, dist=euclidean_norm)
print(d)
# Out:
# 14.776154891304348

# %%
plt.imshow(acc_cost_matrix.T, origin='lower', cmap='gray', interpolation='nearest')
plt.plot(path[0], path[1], 'w')
plt.show()
