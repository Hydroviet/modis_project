# %%
import os
import sys

# %%
sys.path.append('../../../../../..')

# %%
from modis_utils.misc import restore_data

# %%
path = '0.dat'

# %%
a = restore_data('0.dat')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(a[0][-1])

# %%
min_val = 1000
max_val = -2

# %%
for x in os.listdir('.'):
    if x.endswith('.dat'):
        a = restore_data(x)
        min_val = min(min_val, a[1].min())
        max_val = max(max_val, a[1].max())

# %%
min_val, max_val
# Out:
# (-1.891063023506308, 1.7981029618724746)
